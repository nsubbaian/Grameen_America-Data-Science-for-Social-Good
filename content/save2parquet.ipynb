# %%
# Generate and store parquet file of imported xlsx file
import numpy as np
import pandas as pd
import csv
import pyarrow.parquet as pq
print("import complete")

filename = "all_data_retention.xlsx"
savefilename = "all_data_retention_df"

file = pd.read_excel(filename)
file.to_parquet(savefilename, compression=None)
# Out:
# import complete

# %%
# To verify that parquet file was generated properly
dfimport = pd.read_parquet(savefilename)
dfimport
# Out:
#                                          Branch Account Holder ID  \
# 0                  07 - Oakland - SF Bay Area 1            7-1565
# 1                  07 - Oakland - SF Bay Area 1          7-9748.1
# 2               11 - Charlotte - North Carolina        11-10362.1
# 3                 09 - Sunset Park - Brooklyn 2            9-3675
# 4               11 - Charlotte - North Carolina           11-4784
# ...                                         ...               ...
# 98466           11 - Charlotte - North Carolina        11-10074.2
# 98467               08 - Jamaica/LIC - Queens 2          8-6183.2
# 98468           01 - Jackson Heights - Queens 1          1-9712.5
# 98469  18 - San Juan - Grameen Puerto Rico, LLC           18-2744
# 98470           11 - Charlotte - North Carolina            3082.1
#
#       Account Holder ID2  Match? Account ID  Completed Loan Cycles (Member)  \
# 0                 7-1565     1.0    GASR898                            15.0
# ...
